# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import sklearn.metrics

# %%
nround     = 200
repeat     = 10
operator   = 4
newfeature = 64
numcv      = 10
param = {'bst:eta':0.02, 
         'silent' : 1,
         'objective':'binary:logistic',
         'bst:max_depth':11,
         'base_score':0.5,
         'subsample':0.9,
         'bst:colsample_bytree':0.5,
         'scale_pos_weight':1,
         'min_child_weight':5}
plst = param.items()
plst +=  [('eval_metric', 'auc')]
head = []
for i in range(64):
    head.append('X' + str(i+1))
head.append('Y')
Data = []
for i in range(5):
    temp = pd.read_csv('CSV/' + str(i+1) + 'year.csv', names = head, header = None, na_values = '?')
    temp = temp.fillna(temp.median())
    Data.append(temp)

# %%
for i in range(5):
    
    data   = Data[i]
    datay  = data['Y'].copy()
    datax  = data.drop(['Y'], axis = 1)
    p      = np.zeros((datax.shape[1]),dtype = float) + 1/float(datax.shape[1])
    result = pd.DataFrame(index = range(repeat), columns = range(numcv+1))
    
    for k in range(repeat):
        
        for f in range(newfeature):
                
            o  = np.random.randint(operator, size = 1);
            f1 = np.random.multinomial(1, p, size = 1)[0]
            f2 = np.random.multinomial(1, p, size = 1)[0]
                
            if(o == 0):
                c = '(' + datax.columns[f1 == 1][0] + ')+(' + datax.columns[f2 == 1][0] + ')'
                if c not in datax.columns:
                    datax[c] = datax[datax.columns[f1 == 1][0]] + datax[datax.columns[f2 == 1][0]]
                    p        = np.append(p,[0], axis = 0)
            elif(o == 1):
                c = '(' + datax.columns[f1 == 1][0] + ')-(' + datax.columns[f2 == 1][0] + ')'
                if c not in datax.columns:
                    datax[c] = datax[datax.columns[f1 == 1][0]] - datax[datax.columns[f2 == 1][0]]
                    p        = np.append(p,[0], axis = 0)
            elif(o == 2):
                c = '(' + datax.columns[f1 == 1][0] + ')*(' + datax.columns[f2 == 1][0] + ')'
                if c not in datax.columns:
                    datax[c] = datax[datax.columns[f1 == 1][0]] * datax[datax.columns[f2 == 1][0]]
                    p        = np.append(p,[0], axis = 0)
            else:
                c = '(' + datax.columns[f1 == 1][0] + ')/(' + datax.columns[f2 == 1][0] + ')'
                if c not in datax.columns:
                    datax[c] = datax[datax.columns[f1 == 1][0]] / datax[datax.columns[f2 == 1][0]]
                    p        = np.append(p,[0], axis = 0)
        
        cv = np.random.randint(numcv, size = data.shape[0])
        fscore = {}
        
        for j in range(numcv):
            
            trainx = datax[cv != j]
            testx  = datax[cv == j]
            trainy = datay[cv != j]
            testy  = datay[cv == j]
            train  = xgb.DMatrix(trainx, label = trainy)
            test   = xgb.DMatrix(testx, label = testy)
            
            evallist = [(test,'test'), (train,'train')]       
            bst      = xgb.train(plst, train, nround, evallist, early_stopping_rounds = 100)
            result.loc[k, j] = float(bst.eval(test,'test', bst.best_iteration).split(":")[1])
            fs   = bst.get_fscore()
            for key in fs.keys():
                if key in fscore.keys():
                    fscore[key] += fs[key]
                else:
                    fscore[key] = fs[key]
            
        features = {}
        for key in fscore.keys():
            if float(fscore[key]) >= np.percentile(fscore.values(), 10):
                features[key] = float(fscore[key])   
        keys = features.keys()
        p = np.zeros((len(keys)),dtype = float)
        datanew = pd.DataFrame()
        for m in range(len(keys)):
            key = keys[m]
            newdata = datax[key].copy()
            datanew = pd.concat([datanew, newdata], axis = 1)
            p[m] = float(fscore[key])        
        datax = datanew
        p = p/np.sum(p)

        features = pd.Series(p, index = keys)
        features = features.sort_values(ascending = False)
        features.to_csv('R/' + str(i+1) + 'year' + str(k+1) + 'repeat.csv')
        
    result[numcv] = result.mean(1)
    result.to_csv('R/' + str(i+1) + 'yearAuc.csv')
# Out:
# [0]	test-auc:0.724542	train-auc:0.764776
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	test-auc:0.827651	train-auc:0.888012
# [2]	test-auc:0.916587	train-auc:0.94496
# [3]	test-auc:0.919268	train-auc:0.951745
# [4]	test-auc:0.945413	train-auc:0.966993
# [5]	test-auc:0.947105	train-auc:0.973075
# [6]	test-auc:0.951701	train-auc:0.980693
# [7]	test-auc:0.945349	train-auc:0.984076
# [8]	test-auc:0.944455	train-auc:0.987273
# [9]	test-auc:0.942093	train-auc:0.989332
# [10]	test-auc:0.942093	train-auc:0.990236
# [11]	test-auc:0.945477	train-auc:0.99147
# [12]	test-auc:0.94471	train-auc:0.991602
# [13]	test-auc:0.951095	train-auc:0.993872
# [14]	test-auc:0.958118	train-auc:0.994054
# [15]	test-auc:0.963034	train-auc:0.995406
# [16]	test-auc:0.962076	train-auc:0.9957
# [17]	test-auc:0.963225	train-auc:0.996331
# [18]	test-auc:0.964183	train-auc:0.996693
# [19]	test-auc:0.969163	train-auc:0.99693
# [20]	test-auc:0.972483	train-auc:0.997499
# [21]	test-auc:0.969227	train-auc:0.99809
# [22]	test-auc:0.970568	train-auc:0.99843
# [23]	test-auc:0.973121	train-auc:0.99888
# [24]	test-auc:0.974462	train-auc:0.99917
# [25]	test-auc:0.974015	train-auc:0.999336
# [26]	test-auc:0.971908	train-auc:0.999413
# [27]	test-auc:0.971972	train-auc:0.999415
# [28]	test-auc:0.974398	train-auc:0.999576
# [29]	test-auc:0.977144	train-auc:0.99969
# [30]	test-auc:0.975994	train-auc:0.999704
# [31]	test-auc:0.976888	train-auc:0.999788
# [32]	test-auc:0.975484	train-auc:0.999767
# [33]	test-auc:0.976824	train-auc:0.999846
# [34]	test-auc:0.975739	train-auc:0.99984
# [35]	test-auc:0.975292	train-auc:0.999877
# [36]	test-auc:0.974271	train-auc:0.999918
# [37]	test-auc:0.972355	train-auc:0.99994
# [38]	test-auc:0.972355	train-auc:0.99996
# [39]	test-auc:0.974462	train-auc:0.999967
# [40]	test-auc:0.974973	train-auc:0.999974
# [41]	test-auc:0.974462	train-auc:0.999979
# [42]	test-auc:0.974845	train-auc:0.999977
# [43]	test-auc:0.976952	train-auc:0.999984
# [44]	test-auc:0.977974	train-auc:0.999985
# [45]	test-auc:0.977144	train-auc:0.999986
# [46]	test-auc:0.977974	train-auc:0.999989
# [47]	test-auc:0.978676	train-auc:0.999994
# [48]	test-auc:0.978229	train-auc:0.999993
# [49]	test-auc:0.978612	train-auc:0.999996
# [50]	test-auc:0.978931	train-auc:0.999998
# [51]	test-auc:0.979187	train-auc:0.999999
# [52]	test-auc:0.979761	train-auc:0.999999
# [53]	test-auc:0.979314	train-auc:0.999999
# [54]	test-auc:0.978995	train-auc:1
# [55]	test-auc:0.979187	train-auc:1
# [56]	test-auc:0.978867	train-auc:1
# [57]	test-auc:0.978101	train-auc:1
# [58]	test-auc:0.977782	train-auc:1
# [59]	test-auc:0.976952	train-auc:1
# [60]	test-auc:0.97791	train-auc:1
# [61]	test-auc:0.977527	train-auc:1
# [62]	test-auc:0.978612	train-auc:1
# [63]	test-auc:0.978293	train-auc:1
# [64]	test-auc:0.978867	train-auc:1
# [65]	test-auc:0.979059	train-auc:1
# [66]	test-auc:0.978995	train-auc:1
# [67]	test-auc:0.97925	train-auc:1
# [68]	test-auc:0.978229	train-auc:1
# [69]	test-auc:0.977974	train-auc:1
# [70]	test-auc:0.977271	train-auc:1
# [71]	test-auc:0.977144	train-auc:1
# [72]	test-auc:0.977207	train-auc:1
# [73]	test-auc:0.977974	train-auc:1
# [74]	test-auc:0.977399	train-auc:1
# [75]	test-auc:0.977718	train-auc:1
# [76]	test-auc:0.977463	train-auc:1
# [77]	test-auc:0.978293	train-auc:1
# [78]	test-auc:0.977591	train-auc:1
# [79]	test-auc:0.978165	train-auc:1
# [80]	test-auc:0.977591	train-auc:1
# [81]	test-auc:0.977527	train-auc:1
# [82]	test-auc:0.977335	train-auc:1
# [83]	test-auc:0.976952	train-auc:1
# [84]	test-auc:0.977016	train-auc:1
# [85]	test-auc:0.977399	train-auc:1
# [86]	test-auc:0.977271	train-auc:1
# [87]	test-auc:0.977527	train-auc:1
# [88]	test-auc:0.977718	train-auc:1
# [89]	test-auc:0.97708	train-auc:1
# [90]	test-auc:0.977399	train-auc:1
# [91]	test-auc:0.976186	train-auc:1
# [92]	test-auc:0.97625	train-auc:1
# [93]	test-auc:0.976122	train-auc:1
# [94]	test-auc:0.977016	train-auc:1
# [95]	test-auc:0.977271	train-auc:1
# [96]	test-auc:0.97791	train-auc:1
# [97]	test-auc:0.977974	train-auc:1
# [98]	test-auc:0.977463	train-auc:1
# [99]	test-auc:0.977207	train-auc:1
# [100]	test-auc:0.976888	train-auc:1
# [101]	test-auc:0.97625	train-auc:1
# [102]	test-auc:0.976377	train-auc:1
# [103]	test-auc:0.976122	train-auc:1
# [104]	test-auc:0.976824	train-auc:1
# [105]	test-auc:0.977144	train-auc:1
# [106]	test-auc:0.977463	train-auc:1
# [107]	test-auc:0.976824	train-auc:1
# [108]	test-auc:0.97708	train-auc:1
# [109]	test-auc:0.977335	train-auc:1
# [110]	test-auc:0.977207	train-auc:1
# [111]	test-auc:0.976633	train-auc:1
# [112]	test-auc:0.97625	train-auc:1
# [113]	test-auc:0.976186	train-auc:1
# [114]	test-auc:0.975739	train-auc:1
# [115]	test-auc:0.975547	train-auc:1
# [116]	test-auc:0.975803	train-auc:1
# [117]	test-auc:0.976122	train-auc:1
# [118]	test-auc:0.976122	train-auc:1
# [119]	test-auc:0.975739	train-auc:1
# [120]	test-auc:0.976377	train-auc:1
# [121]	test-auc:0.976952	train-auc:1
# [122]	test-auc:0.976441	train-auc:1
# [123]	test-auc:0.97625	train-auc:1
# [124]	test-auc:0.976186	train-auc:1
# [125]	test-auc:0.975994	train-auc:1
# [126]	test-auc:0.975611	train-auc:1
# [127]	test-auc:0.975228	train-auc:1
# [128]	test-auc:0.974909	train-auc:1
# [129]	test-auc:0.974654	train-auc:1
# [130]	test-auc:0.974845	train-auc:1
# [131]	test-auc:0.974207	train-auc:1
# [132]	test-auc:0.974526	train-auc:1
# [133]	test-auc:0.974334	train-auc:1
# [134]	test-auc:0.974015	train-auc:1
# [135]	test-auc:0.973888	train-auc:1
# [136]	test-auc:0.973951	train-auc:1
# [137]	test-auc:0.973824	train-auc:1
# [138]	test-auc:0.974398	train-auc:1
# [139]	test-auc:0.974207	train-auc:1
# [140]	test-auc:0.974271	train-auc:1
# [141]	test-auc:0.973632	train-auc:1
# [142]	test-auc:0.974015	train-auc:1
# [143]	test-auc:0.973951	train-auc:1
# [144]	test-auc:0.973888	train-auc:1
# [145]	test-auc:0.973441	train-auc:1
# [146]	test-auc:0.973441	train-auc:1
# [147]	test-auc:0.974207	train-auc:1
# [148]	test-auc:0.973824	train-auc:1
# [149]	test-auc:0.973185	train-auc:1
# [150]	test-auc:0.973951	train-auc:1
# [151]	test-auc:0.973632	train-auc:1
# [152]	test-auc:0.973185	train-auc:1
# [153]	test-auc:0.973058	train-auc:1
# [154]	test-auc:0.973249	train-auc:1
# Stopping. Best iteration:
# [54]	test-auc:0.978995	train-auc:1
#
# [0]	test-auc:0.876242	train-auc:0.885171
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	test-auc:0.916869	train-auc:0.91371
# [2]	test-auc:0.969053	train-auc:0.955368
# [3]	test-auc:0.962581	train-auc:0.956564
# [4]	test-auc:0.964806	train-auc:0.97555
# [5]	test-auc:0.963766	train-auc:0.976489
# [6]	test-auc:0.979947	train-auc:0.98119
# [7]	test-auc:0.980525	train-auc:0.984166
# [8]	test-auc:0.982287	train-auc:0.986448
# [9]	test-auc:0.980698	train-auc:0.989478
# [10]	test-auc:0.981854	train-auc:0.990326
# [11]	test-auc:0.97752	train-auc:0.9915
# [12]	test-auc:0.977346	train-auc:0.99292
# [13]	test-auc:0.975613	train-auc:0.99386
# [14]	test-auc:0.978098	train-auc:0.994665
# [15]	test-auc:0.977462	train-auc:0.995859
# [16]	test-auc:0.975902	train-auc:0.996623
# [17]	test-auc:0.977057	train-auc:0.996849
# [18]	test-auc:0.978155	train-auc:0.99709
# [19]	test-auc:0.978791	train-auc:0.997483
# [20]	test-auc:0.978733	train-auc:0.998149
# [21]	test-auc:0.977924	train-auc:0.998283
# [22]	test-auc:0.979311	train-auc:0.998754
# [23]	test-auc:0.978387	train-auc:0.998957
# [24]	test-auc:0.978444	train-auc:0.999073
# [25]	test-auc:0.982258	train-auc:0.999237
# [26]	test-auc:0.984165	train-auc:0.999413
# [27]	test-auc:0.984512	train-auc:0.999544
# [28]	test-auc:0.983703	train-auc:0.999596
# [29]	test-auc:0.984397	train-auc:0.999609
# [30]	test-auc:0.983125	train-auc:0.999669
# [31]	test-auc:0.984339	train-auc:0.999705
# [32]	test-auc:0.984512	train-auc:0.999768
# [33]	test-auc:0.982894	train-auc:0.999747
# [34]	test-auc:0.981507	train-auc:0.999819
# [35]	test-auc:0.97908	train-auc:0.999856
# [36]	test-auc:0.981449	train-auc:0.999899
# [37]	test-auc:0.983299	train-auc:0.999886
# [38]	test-auc:0.98301	train-auc:0.999886
# [39]	test-auc:0.984223	train-auc:0.999932
# [40]	test-auc:0.983819	train-auc:0.999941
# [41]	test-auc:0.983356	train-auc:0.999969
# [42]	test-auc:0.984917	train-auc:0.999974
# [43]	test-auc:0.985032	train-auc:0.999979
# [44]	test-auc:0.985841	train-auc:0.999982
# [45]	test-auc:0.986188	train-auc:0.999991
# [46]	test-auc:0.986593	train-auc:0.999994
# [47]	test-auc:0.986824	train-auc:0.999991
# [48]	test-auc:0.986073	train-auc:0.999996
# [49]	test-auc:0.98561	train-auc:0.999998
# [50]	test-auc:0.986073	train-auc:0.999998
# [51]	test-auc:0.985264	train-auc:0.999996
# [52]	test-auc:0.984975	train-auc:0.999999
# [53]	test-auc:0.984801	train-auc:0.999998
# [54]	test-auc:0.983819	train-auc:0.999999
# [55]	test-auc:0.984281	train-auc:0.999999
# [56]	test-auc:0.983761	train-auc:1
# [57]	test-auc:0.983068	train-auc:1
# [58]	test-auc:0.984686	train-auc:1
# [59]	test-auc:0.985206	train-auc:1
# [60]	test-auc:0.985495	train-auc:1
# [61]	test-auc:0.986477	train-auc:1
# [62]	test-auc:0.985552	train-auc:1
# [63]	test-auc:0.986304	train-auc:1
# [64]	test-auc:0.98665	train-auc:1
# [65]	test-auc:0.986882	train-auc:1
# [66]	test-auc:0.986419	train-auc:1
# [67]	test-auc:0.986246	train-auc:1
# [68]	test-auc:0.986015	train-auc:1
# [69]	test-auc:0.986419	train-auc:1
# [70]	test-auc:0.986824	train-auc:1
# [71]	test-auc:0.986535	train-auc:1
# [72]	test-auc:0.98746	train-auc:1
# [73]	test-auc:0.987344	train-auc:1
# [74]	test-auc:0.987749	train-auc:1
# [75]	test-auc:0.986766	train-auc:1
# [76]	test-auc:0.986939	train-auc:1
# [77]	test-auc:0.986939	train-auc:1
# [78]	test-auc:0.986997	train-auc:1
# [79]	test-auc:0.98665	train-auc:1
# [80]	test-auc:0.987575	train-auc:1
# [81]	test-auc:0.987402	train-auc:1
# [82]	test-auc:0.987806	train-auc:1
# [83]	test-auc:0.987749	train-auc:1
# [84]	test-auc:0.987575	train-auc:1
# [85]	test-auc:0.98798	train-auc:1
# [86]	test-auc:0.987575	train-auc:1
# [87]	test-auc:0.98798	train-auc:1
# [88]	test-auc:0.988211	train-auc:1
# [89]	test-auc:0.988326	train-auc:1
# [90]	test-auc:0.988153	train-auc:1
# [91]	test-auc:0.988269	train-auc:1
# [92]	test-auc:0.988789	train-auc:1
# [93]	test-auc:0.989251	train-auc:1
# [94]	test-auc:0.988962	train-auc:1
# [95]	test-auc:0.988846	train-auc:1
# [96]	test-auc:0.988615	train-auc:1
# [97]	test-auc:0.988037	train-auc:1
# [98]	test-auc:0.988211	train-auc:1
# [99]	test-auc:0.9885	train-auc:1
# [100]	test-auc:0.988442	train-auc:1
# [101]	test-auc:0.988211	train-auc:1
# [102]	test-auc:0.988789	train-auc:1
# [103]	test-auc:0.98902	train-auc:1
# [104]	test-auc:0.988673	train-auc:1
# [105]	test-auc:0.9885	train-auc:1
# [106]	test-auc:0.988615	train-auc:1
# [107]	test-auc:0.988558	train-auc:1
# [108]	test-auc:0.988442	train-auc:1
# [109]	test-auc:0.987864	train-auc:1
# [110]	test-auc:0.987806	train-auc:1
# [111]	test-auc:0.987749	train-auc:1
# [112]	test-auc:0.987806	train-auc:1
# [113]	test-auc:0.987806	train-auc:1
# [114]	test-auc:0.987922	train-auc:1
# [115]	test-auc:0.987922	train-auc:1
# [116]	test-auc:0.988269	train-auc:1
# [117]	test-auc:0.988037	train-auc:1
# [118]	test-auc:0.987517	train-auc:1
# [119]	test-auc:0.988095	train-auc:1
# [120]	test-auc:0.988153	train-auc:1
# [121]	test-auc:0.988037	train-auc:1
# [122]	test-auc:0.988037	train-auc:1
# [123]	test-auc:0.988095	train-auc:1
# [124]	test-auc:0.988095	train-auc:1
# [125]	test-auc:0.987864	train-auc:1
# [126]	test-auc:0.987633	train-auc:1
# [127]	test-auc:0.987344	train-auc:1
# [128]	test-auc:0.987402	train-auc:1
# [129]	test-auc:0.987402	train-auc:1
# [130]	test-auc:0.98746	train-auc:1
# [131]	test-auc:0.987922	train-auc:1
# [132]	test-auc:0.988269	train-auc:1
# [133]	test-auc:0.988037	train-auc:1
# [134]	test-auc:0.987864	train-auc:1
# [135]	test-auc:0.988211	train-auc:1
# [136]	test-auc:0.988153	train-auc:1
# [137]	test-auc:0.988095	train-auc:1
# [138]	test-auc:0.987922	train-auc:1
# [139]	test-auc:0.987922	train-auc:1
# [140]	test-auc:0.988153	train-auc:1
# [141]	test-auc:0.987749	train-auc:1
# [142]	test-auc:0.988037	train-auc:1
# [143]	test-auc:0.987864	train-auc:1
# [144]	test-auc:0.987633	train-auc:1
# [145]	test-auc:0.98746	train-auc:1
# [146]	test-auc:0.987402	train-auc:1
# [147]	test-auc:0.987575	train-auc:1
# [148]	test-auc:0.987402	train-auc:1
# [149]	test-auc:0.987633	train-auc:1
# [150]	test-auc:0.987171	train-auc:1
# [151]	test-auc:0.986997	train-auc:1
# [152]	test-auc:0.986882	train-auc:1
# [153]	test-auc:0.986824	train-auc:1
# [154]	test-auc:0.987113	train-auc:1
# [155]	test-auc:0.986766	train-auc:1
# [156]	test-auc:0.986882	train-auc:1
# Stopping. Best iteration:
# [56]	test-auc:0.983761	train-auc:1
#
# [0]	test-auc:0.810727	train-auc:0.865167
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	test-auc:0.872417	train-auc:0.926453
# [2]	test-auc:0.932503	train-auc:0.960866
# [3]	test-auc:0.946977	train-auc:0.964562
# [4]	test-auc:0.951091	train-auc:0.972519
# [5]	test-auc:0.949691	train-auc:0.975463
# [6]	test-auc:0.954827	train-auc:0.978438
# [7]	test-auc:0.962472	train-auc:0.98079
# [8]	test-auc:0.962005	train-auc:0.98293
# [9]	test-auc:0.958708	train-auc:0.987248
# [10]	test-auc:0.959291	train-auc:0.987936
# [11]	test-auc:0.964136	train-auc:0.990026
# [12]	test-auc:0.969009	train-auc:0.991842
# [13]	test-auc:0.971402	train-auc:0.992583
# [14]	test-auc:0.968717	train-auc:0.994152
# [15]	test-auc:0.968951	train-auc:0.995408
# [16]	test-auc:0.97502	train-auc:0.99608
# [17]	test-auc:0.977122	train-auc:0.996519
# [18]	test-auc:0.975662	train-auc:0.997484
# [19]	test-auc:0.976771	train-auc:0.998052
# [20]	test-auc:0.975487	train-auc:0.998255
# [21]	test-auc:0.976946	train-auc:0.998604
# [22]	test-auc:0.975254	train-auc:0.998984
# [23]	test-auc:0.976888	train-auc:0.999022
# [24]	test-auc:0.97502	train-auc:0.999323
# [25]	test-auc:0.974087	train-auc:0.999399
# [26]	test-auc:0.974437	train-auc:0.999509
# [27]	test-auc:0.973503	train-auc:0.999592
# [28]	test-auc:0.975196	train-auc:0.999683
# [29]	test-auc:0.977705	train-auc:0.999759
# [30]	test-auc:0.979923	train-auc:0.999872
# [31]	test-auc:0.979281	train-auc:0.999912
# [32]	test-auc:0.979223	train-auc:0.999943
# [33]	test-auc:0.979631	train-auc:0.99996
# [34]	test-auc:0.97823	train-auc:0.999958
# [35]	test-auc:0.980098	train-auc:0.999954
# [36]	test-auc:0.980682	train-auc:0.999973
# [37]	test-auc:0.979923	train-auc:0.999986
# [38]	test-auc:0.977939	train-auc:0.999991
# [39]	test-auc:0.979398	train-auc:0.999987
# [40]	test-auc:0.977005	train-auc:0.999995
# [41]	test-auc:0.976304	train-auc:0.999994
# [42]	test-auc:0.976421	train-auc:0.999995
# [43]	test-auc:0.977764	train-auc:0.999995
# [44]	test-auc:0.97648	train-auc:0.999996
# [45]	test-auc:0.974787	train-auc:0.999997
# [46]	test-auc:0.974612	train-auc:0.999997
# [47]	test-auc:0.975429	train-auc:0.999997
# [48]	test-auc:0.97467	train-auc:0.999997
# [49]	test-auc:0.974787	train-auc:1
# [50]	test-auc:0.975604	train-auc:1
# [51]	test-auc:0.97502	train-auc:1
# [52]	test-auc:0.974612	train-auc:1
# [53]	test-auc:0.974962	train-auc:1
# [54]	test-auc:0.974437	train-auc:1
# [55]	test-auc:0.97502	train-auc:1
# [56]	test-auc:0.976713	train-auc:1
# [57]	test-auc:0.975546	train-auc:1
# [58]	test-auc:0.975429	train-auc:1
# [59]	test-auc:0.975371	train-auc:1
# [60]	test-auc:0.975954	train-auc:1
# [61]	test-auc:0.975079	train-auc:1
# [62]	test-auc:0.975137	train-auc:1
# [63]	test-auc:0.97683	train-auc:1
# [64]	test-auc:0.976013	train-auc:1
# [65]	test-auc:0.975312	train-auc:1
# [66]	test-auc:0.974612	train-auc:1
# [67]	test-auc:0.975429	train-auc:1
# [68]	test-auc:0.97648	train-auc:1
# [69]	test-auc:0.977705	train-auc:1
# [70]	test-auc:0.977647	train-auc:1
# [71]	test-auc:0.976888	train-auc:1
# [72]	test-auc:0.976129	train-auc:1
# [73]	test-auc:0.976596	train-auc:1
# [74]	test-auc:0.97718	train-auc:1
# [75]	test-auc:0.976771	train-auc:1
# [76]	test-auc:0.977764	train-auc:1
# [77]	test-auc:0.97683	train-auc:1
# [78]	test-auc:0.976304	train-auc:1
# [79]	test-auc:0.976246	train-auc:1
# [80]	test-auc:0.97648	train-auc:1
# [81]	test-auc:0.976071	train-auc:1
# [82]	test-auc:0.976421	train-auc:1
# [83]	test-auc:0.975662	train-auc:1
# [84]	test-auc:0.975546	train-auc:1
# [85]	test-auc:0.974845	train-auc:1
# [86]	test-auc:0.975079	train-auc:1
# [87]	test-auc:0.974729	train-auc:1
# [88]	test-auc:0.97502	train-auc:1
# [89]	test-auc:0.974495	train-auc:1
# [90]	test-auc:0.974612	train-auc:1
# [91]	test-auc:0.974904	train-auc:1
# [92]	test-auc:0.974378	train-auc:1
# [93]	test-auc:0.974554	train-auc:1
# [94]	test-auc:0.97432	train-auc:1
# [95]	test-auc:0.975429	train-auc:1
# [96]	test-auc:0.975779	train-auc:1
# [97]	test-auc:0.97502	train-auc:1
# [98]	test-auc:0.974904	train-auc:1
# [99]	test-auc:0.974729	train-auc:1
# [100]	test-auc:0.974845	train-auc:1
# [101]	test-auc:0.975546	train-auc:1
# [102]	test-auc:0.975196	train-auc:1
# [103]	test-auc:0.975371	train-auc:1
# [104]	test-auc:0.975487	train-auc:1
# [105]	test-auc:0.97502	train-auc:1
# [106]	test-auc:0.975838	train-auc:1
# [107]	test-auc:0.976246	train-auc:1
# [108]	test-auc:0.976421	train-auc:1
# [109]	test-auc:0.976071	train-auc:1
# [110]	test-auc:0.976129	train-auc:1
# [111]	test-auc:0.975079	train-auc:1
# [112]	test-auc:0.97502	train-auc:1
# [113]	test-auc:0.974962	train-auc:1
# [114]	test-auc:0.974729	train-auc:1
# [115]	test-auc:0.974612	train-auc:1
# [116]	test-auc:0.97467	train-auc:1
# [117]	test-auc:0.974495	train-auc:1
# [118]	test-auc:0.974612	train-auc:1
# [119]	test-auc:0.974612	train-auc:1
# [120]	test-auc:0.974612	train-auc:1
# [121]	test-auc:0.974612	train-auc:1
# [122]	test-auc:0.974495	train-auc:1
# [123]	test-auc:0.975429	train-auc:1
# [124]	test-auc:0.975604	train-auc:1
# [125]	test-auc:0.975721	train-auc:1
# [126]	test-auc:0.975779	train-auc:1
# [127]	test-auc:0.976246	train-auc:1
# [128]	test-auc:0.975721	train-auc:1
# [129]	test-auc:0.97502	train-auc:1
# [130]	test-auc:0.974962	train-auc:1
# [131]	test-auc:0.975137	train-auc:1
# [132]	test-auc:0.975079	train-auc:1
# [133]	test-auc:0.975487	train-auc:1
# [134]	test-auc:0.974962	train-auc:1
# [135]	test-auc:0.975371	train-auc:1
# [136]	test-auc:0.975896	train-auc:1
# [137]	test-auc:0.975487	train-auc:1
# [138]	test-auc:0.975196	train-auc:1
# [139]	test-auc:0.975254	train-auc:1
# [140]	test-auc:0.975137	train-auc:1
# [141]	test-auc:0.975429	train-auc:1
# [142]	test-auc:0.975954	train-auc:1
# [143]	test-auc:0.976013	train-auc:1
# [144]	test-auc:0.975721	train-auc:1
# [145]	test-auc:0.97502	train-auc:1
# [146]	test-auc:0.975254	train-auc:1
# [147]	test-auc:0.975312	train-auc:1
# [148]	test-auc:0.974962	train-auc:1
# [149]	test-auc:0.974729	train-auc:1
# Stopping. Best iteration:
# [49]	test-auc:0.974787	train-auc:1
#
# [0]	test-auc:0.692797	train-auc:0.808405
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	test-auc:0.892044	train-auc:0.950297
# [2]	test-auc:0.917483	train-auc:0.961937
# [3]	test-auc:0.927725	train-auc:0.962525
# [4]	test-auc:0.928002	train-auc:0.972623
# [5]	test-auc:0.92839	train-auc:0.977797
# [6]	test-auc:0.936002	train-auc:0.981912
# [7]	test-auc:0.935919	train-auc:0.985321
# [8]	test-auc:0.930493	train-auc:0.985982
# [9]	test-auc:0.928057	train-auc:0.987029
# [10]	test-auc:0.92814	train-auc:0.987824
# [11]	test-auc:0.931047	train-auc:0.988785
# [12]	test-auc:0.955821	train-auc:0.989727
# [13]	test-auc:0.957759	train-auc:0.991602
# [14]	test-auc:0.958922	train-auc:0.994425
# [15]	test-auc:0.95715	train-auc:0.995258
# [16]	test-auc:0.955766	train-auc:0.996406
# [17]	test-auc:0.961966	train-auc:0.99687
# [18]	test-auc:0.961413	train-auc:0.997096
# [19]	test-auc:0.962686	train-auc:0.997822
# [20]	test-auc:0.965399	train-auc:0.997956
# [21]	test-auc:0.961856	train-auc:0.998496
# [22]	test-auc:0.958922	train-auc:0.998923
# [23]	test-auc:0.965011	train-auc:0.999167
# [24]	test-auc:0.966174	train-auc:0.999325
# [25]	test-auc:0.964956	train-auc:0.99952
# [26]	test-auc:0.964956	train-auc:0.999604
# [27]	test-auc:0.969108	train-auc:0.999714
# [28]	test-auc:0.969551	train-auc:0.999796
# [29]	test-auc:0.969939	train-auc:0.999857
# [30]	test-auc:0.970271	train-auc:0.999912
# [31]	test-auc:0.970714	train-auc:0.999931
# [32]	test-auc:0.970215	train-auc:0.999949
# [33]	test-auc:0.969662	train-auc:0.99997
# [34]	test-auc:0.972707	train-auc:0.999976
# [35]	test-auc:0.972817	train-auc:0.999987
# [36]	test-auc:0.972928	train-auc:0.999991
# [37]	test-auc:0.972319	train-auc:0.999996
# [38]	test-auc:0.971544	train-auc:0.999992
# [39]	test-auc:0.971655	train-auc:0.999997
# [40]	test-auc:0.97088	train-auc:0.999997
# [41]	test-auc:0.971821	train-auc:0.999999
# [42]	test-auc:0.970215	train-auc:0.999999
# [43]	test-auc:0.969883	train-auc:0.999999
# [44]	test-auc:0.97099	train-auc:0.999999
# [45]	test-auc:0.969274	train-auc:1
# [46]	test-auc:0.969496	train-auc:0.999999
# [47]	test-auc:0.970548	train-auc:0.999999
# [48]	test-auc:0.969274	train-auc:0.999999
# [49]	test-auc:0.969994	train-auc:0.999999
# [50]	test-auc:0.970271	train-auc:1
# [51]	test-auc:0.969219	train-auc:0.999999
# [52]	test-auc:0.969828	train-auc:0.999999
# [53]	test-auc:0.970603	train-auc:0.999999
# [54]	test-auc:0.970215	train-auc:1
# [55]	test-auc:0.969219	train-auc:1
# [56]	test-auc:0.96933	train-auc:1
# [57]	test-auc:0.969772	train-auc:1
# [58]	test-auc:0.968942	train-auc:1
# [59]	test-auc:0.969219	train-auc:1
# [60]	test-auc:0.967946	train-auc:1
# [61]	test-auc:0.969163	train-auc:1
# [62]	test-auc:0.970271	train-auc:1
# [63]	test-auc:0.970326	train-auc:1
# [64]	test-auc:0.970105	train-auc:1
# [65]	test-auc:0.969606	train-auc:1
# [66]	test-auc:0.969496	train-auc:1
# [67]	test-auc:0.970215	train-auc:1
# [68]	test-auc:0.970215	train-auc:1
# [69]	test-auc:0.969163	train-auc:1
# [70]	test-auc:0.969606	train-auc:1
# [71]	test-auc:0.969994	train-auc:1
# [72]	test-auc:0.970492	train-auc:1
# [73]	test-auc:0.970824	train-auc:1
# [74]	test-auc:0.971544	train-auc:1
# [75]	test-auc:0.971489	train-auc:1
# [76]	test-auc:0.972264	train-auc:1
# [77]	test-auc:0.972264	train-auc:1
# [78]	test-auc:0.971821	train-auc:1
# [79]	test-auc:0.971046	train-auc:1
# [80]	test-auc:0.971544	train-auc:1
# [81]	test-auc:0.97099	train-auc:1
# [82]	test-auc:0.971212	train-auc:1
# [83]	test-auc:0.971489	train-auc:1
# [84]	test-auc:0.971544	train-auc:1
# [85]	test-auc:0.971876	train-auc:1
# [86]	test-auc:0.970658	train-auc:1
# [87]	test-auc:0.971157	train-auc:1
# [88]	test-auc:0.970658	train-auc:1
# [89]	test-auc:0.970381	train-auc:1
# [90]	test-auc:0.97016	train-auc:1
# [91]	test-auc:0.969551	train-auc:1
# [92]	test-auc:0.969551	train-auc:1
# [93]	test-auc:0.969772	train-auc:1
# [94]	test-auc:0.96944	train-auc:1
# [95]	test-auc:0.97016	train-auc:1
# [96]	test-auc:0.969717	train-auc:1
# [97]	test-auc:0.970271	train-auc:1
# [98]	test-auc:0.970492	train-auc:1
# [99]	test-auc:0.97088	train-auc:1
# [100]	test-auc:0.970215	train-auc:1
# [101]	test-auc:0.970824	train-auc:1
# [102]	test-auc:0.971101	train-auc:1
# [103]	test-auc:0.970105	train-auc:1
# [104]	test-auc:0.969772	train-auc:1
# [105]	test-auc:0.968997	train-auc:1
# [106]	test-auc:0.969053	train-auc:1
# [107]	test-auc:0.968831	train-auc:1
# [108]	test-auc:0.968997	train-auc:1
# [109]	test-auc:0.967835	train-auc:1
# [110]	test-auc:0.967835	train-auc:1
# [111]	test-auc:0.968333	train-auc:1
# [112]	test-auc:0.968444	train-auc:1
# [113]	test-auc:0.968831	train-auc:1
# [114]	test-auc:0.968112	train-auc:1
# [115]	test-auc:0.967503	train-auc:1
# [116]	test-auc:0.968222	train-auc:1
# [117]	test-auc:0.968001	train-auc:1
# [118]	test-auc:0.967558	train-auc:1
# [119]	test-auc:0.967392	train-auc:1
# [120]	test-auc:0.966949	train-auc:1
# [121]	test-auc:0.967004	train-auc:1
# [122]	test-auc:0.96706	train-auc:1
# [123]	test-auc:0.96717	train-auc:1
# [124]	test-auc:0.966894	train-auc:1
# [125]	test-auc:0.966783	train-auc:1
# [126]	test-auc:0.967337	train-auc:1
# [127]	test-auc:0.968056	train-auc:1
# [128]	test-auc:0.967337	train-auc:1
# [129]	test-auc:0.966949	train-auc:1
# [130]	test-auc:0.967004	train-auc:1
# [131]	test-auc:0.968167	train-auc:1
# [132]	test-auc:0.967613	train-auc:1
# [133]	test-auc:0.968056	train-auc:1
# [134]	test-auc:0.967004	train-auc:1
# [135]	test-auc:0.967337	train-auc:1
# [136]	test-auc:0.966728	train-auc:1
# [137]	test-auc:0.966949	train-auc:1
# [138]	test-auc:0.966838	train-auc:1
# [139]	test-auc:0.966949	train-auc:1
# [140]	test-auc:0.966783	train-auc:1
# [141]	test-auc:0.966617	train-auc:1
# [142]	test-auc:0.966894	train-auc:1
# [143]	test-auc:0.966617	train-auc:1
# [144]	test-auc:0.967004	train-auc:1
# [145]	test-auc:0.968721	train-auc:1
# Stopping. Best iteration:
# [45]	test-auc:0.969274	train-auc:1
#
# [0]	test-auc:0.768192	train-auc:0.80144
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	test-auc:0.865322	train-auc:0.946938
# [2]	test-auc:0.87063	train-auc:0.953502
# [3]	test-auc:0.865926	train-auc:0.959706
# [4]	test-auc:0.881355	train-auc:0.979254
# [5]	test-auc:0.883168	train-auc:0.983284
# [6]	test-auc:0.877773	train-auc:0.986864
# [7]	test-auc:0.877492	train-auc:0.988934
# [8]	test-auc:0.884635	train-auc:0.99079
# [9]	test-auc:0.880557	train-auc:0.992626
# [10]	test-auc:0.888196	train-auc:0.994315
# [11]	test-auc:0.900302	train-auc:0.994946
# [12]	test-auc:0.90451	train-auc:0.995444
# [13]	test-auc:0.907488	train-auc:0.996198
# [14]	test-auc:0.9112	train-auc:0.996968
# [15]	test-auc:0.912624	train-auc:0.997665
# [16]	test-auc:0.907164	train-auc:0.997977
# [17]	test-auc:0.913207	train-auc:0.99859
# [18]	test-auc:0.920716	train-auc:0.998787
# [19]	test-auc:0.920889	train-auc:0.998978
# [20]	test-auc:0.924126	train-auc:0.99914
# [21]	test-auc:0.925464	train-auc:0.999301
# [22]	test-auc:0.923824	train-auc:0.999435
# [23]	test-auc:0.92896	train-auc:0.999483
# [24]	test-auc:0.930211	train-auc:0.999589
# [25]	test-auc:0.926198	train-auc:0.999702
# [26]	test-auc:0.929305	train-auc:0.999793
# [27]	test-auc:0.930514	train-auc:0.999864
# [28]	test-auc:0.927967	train-auc:0.999893
# [29]	test-auc:0.933707	train-auc:0.99992
# [30]	test-auc:0.934268	train-auc:0.999942
# [31]	test-auc:0.933448	train-auc:0.999951
# [32]	test-auc:0.931204	train-auc:0.999962
# [33]	test-auc:0.928528	train-auc:0.999971
# [34]	test-auc:0.928269	train-auc:0.999982
# [35]	test-auc:0.925248	train-auc:0.99998
# [36]	test-auc:0.923824	train-auc:0.999989
# [37]	test-auc:0.923867	train-auc:0.999989
# [38]	test-auc:0.925939	train-auc:0.999993
# [39]	test-auc:0.925852	train-auc:0.999997
# [40]	test-auc:0.927967	train-auc:0.999997
# [41]	test-auc:0.92801	train-auc:0.999997
# [42]	test-auc:0.930902	train-auc:0.999998
# [43]	test-auc:0.929564	train-auc:0.999999
# [44]	test-auc:0.927665	train-auc:1
# [45]	test-auc:0.929564	train-auc:1
# [46]	test-auc:0.929391	train-auc:1
# [47]	test-auc:0.929391	train-auc:1
# [48]	test-auc:0.929607	train-auc:1
# [49]	test-auc:0.929953	train-auc:1
# [50]	test-auc:0.930082	train-auc:1
# [51]	test-auc:0.931032	train-auc:1
# [52]	test-auc:0.933837	train-auc:1
# [53]	test-auc:0.933189	train-auc:1
# [54]	test-auc:0.931118	train-auc:1
# [55]	test-auc:0.931506	train-auc:1
# [56]	test-auc:0.930751	train-auc:1
# [57]	test-auc:0.928485	train-auc:1
# [58]	test-auc:0.929305	train-auc:1
# [59]	test-auc:0.927665	train-auc:1
# [60]	test-auc:0.928485	train-auc:1
# [61]	test-auc:0.930298	train-auc:1
# [62]	test-auc:0.931161	train-auc:1
# [63]	test-auc:0.933146	train-auc:1
# [64]	test-auc:0.934182	train-auc:1
# [65]	test-auc:0.936383	train-auc:1
# [66]	test-auc:0.935865	train-auc:1
# [67]	test-auc:0.934916	train-auc:1
# [68]	test-auc:0.934312	train-auc:1
# [69]	test-auc:0.936081	train-auc:1
# [70]	test-auc:0.93483	train-auc:1
# [71]	test-auc:0.935391	train-auc:1
# [72]	test-auc:0.93647	train-auc:1
# [73]	test-auc:0.937851	train-auc:1
# [74]	test-auc:0.93798	train-auc:1
# [75]	test-auc:0.938584	train-auc:1
# [76]	test-auc:0.938412	train-auc:1
# [77]	test-auc:0.940181	train-auc:1
# [78]	test-auc:0.941476	train-auc:1
# [79]	test-auc:0.941476	train-auc:1
# [80]	test-auc:0.940786	train-auc:1
# [81]	test-auc:0.941303	train-auc:1
# [82]	test-auc:0.941131	train-auc:1
# [83]	test-auc:0.94126	train-auc:1
# [84]	test-auc:0.940095	train-auc:1
# [85]	test-auc:0.941951	train-auc:1
# [86]	test-auc:0.943073	train-auc:1
# [87]	test-auc:0.943116	train-auc:1
# [88]	test-auc:0.942857	train-auc:1
# [89]	test-auc:0.942037	train-auc:1
# [90]	test-auc:0.941951	train-auc:1
# [91]	test-auc:0.942382	train-auc:1
# [92]	test-auc:0.941088	train-auc:1
# [93]	test-auc:0.941692	train-auc:1
# [94]	test-auc:0.942037	train-auc:1
# [95]	test-auc:0.941692	train-auc:1
# [96]	test-auc:0.94221	train-auc:1
# [97]	test-auc:0.941821	train-auc:1
# [98]	test-auc:0.942167	train-auc:1
# [99]	test-auc:0.942167	train-auc:1
# [100]	test-auc:0.941217	train-auc:1
# [101]	test-auc:0.940742	train-auc:1
# [102]	test-auc:0.941174	train-auc:1
# [103]	test-auc:0.94044	train-auc:1
# [104]	test-auc:0.940009	train-auc:1
# [105]	test-auc:0.940397	train-auc:1
# [106]	test-auc:0.940786	train-auc:1
# [107]	test-auc:0.940829	train-auc:1
# [108]	test-auc:0.940483	train-auc:1
# [109]	test-auc:0.939663	train-auc:1
# [110]	test-auc:0.940268	train-auc:1
# [111]	test-auc:0.940138	train-auc:1
# [112]	test-auc:0.940268	train-auc:1
# [113]	test-auc:0.941303	train-auc:1
# [114]	test-auc:0.942167	train-auc:1
# [115]	test-auc:0.942296	train-auc:1
# [116]	test-auc:0.942382	train-auc:1
# [117]	test-auc:0.942728	train-auc:1
# [118]	test-auc:0.942987	train-auc:1
# [119]	test-auc:0.942771	train-auc:1
# [120]	test-auc:0.943332	train-auc:1
# [121]	test-auc:0.9429	train-auc:1
# [122]	test-auc:0.942771	train-auc:1
# [123]	test-auc:0.941778	train-auc:1
# [124]	test-auc:0.941821	train-auc:1
# [125]	test-auc:0.941347	train-auc:1
# [126]	test-auc:0.942426	train-auc:1
# [127]	test-auc:0.941735	train-auc:1
# [128]	test-auc:0.942987	train-auc:1
# [129]	test-auc:0.942857	train-auc:1
# [130]	test-auc:0.943548	train-auc:1
# [131]	test-auc:0.944195	train-auc:1
# [132]	test-auc:0.944325	train-auc:1
# [133]	test-auc:0.944022	train-auc:1
# [134]	test-auc:0.944799	train-auc:1
# [135]	test-auc:0.94454	train-auc:1
# [136]	test-auc:0.945101	train-auc:1
# [137]	test-auc:0.94467	train-auc:1
# [138]	test-auc:0.943548	train-auc:1
# [139]	test-auc:0.943418	train-auc:1
# [140]	test-auc:0.942728	train-auc:1
# [141]	test-auc:0.943202	train-auc:1
# [142]	test-auc:0.942512	train-auc:1
# [143]	test-auc:0.943246	train-auc:1
# [144]	test-auc:0.942771	train-auc:1
# Stopping. Best iteration:
# [44]	test-auc:0.927665	train-auc:1
#
# [0]	test-auc:0.797204	train-auc:0.759269
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	test-auc:0.936422	train-auc:0.935152
# [2]	test-auc:0.94683	train-auc:0.964857
# [3]	test-auc:0.953506	train-auc:0.963977
# [4]	test-auc:0.955898	train-auc:0.972058
# [5]	test-auc:0.959078	train-auc:0.976011
# [6]	test-auc:0.952928	train-auc:0.981417
# [7]	test-auc:0.952796	train-auc:0.982346
# [8]	test-auc:0.959078	train-auc:0.983775
# [9]	test-auc:0.971983	train-auc:0.984739
# [10]	test-auc:0.971405	train-auc:0.988001
# [11]	test-auc:0.972982	train-auc:0.990811
# [12]	test-auc:0.980761	train-auc:0.99282
# [13]	test-auc:0.980078	train-auc:0.993915
# [14]	test-auc:0.98197	train-auc:0.994325
# [15]	test-auc:0.986281	train-auc:0.995515
# [16]	test-auc:0.98565	train-auc:0.995568
# [17]	test-auc:0.986806	train-auc:0.996317
# [18]	test-auc:0.987332	train-auc:0.997006
# [19]	test-auc:0.988173	train-auc:0.99774
# [20]	test-auc:0.990223	train-auc:0.998288
# [21]	test-auc:0.990013	train-auc:0.998302
# [22]	test-auc:0.989908	train-auc:0.998562
# [23]	test-auc:0.991379	train-auc:0.99886
# [24]	test-auc:0.990118	train-auc:0.999108
# [25]	test-auc:0.990013	train-auc:0.999283
# [26]	test-auc:0.98954	train-auc:0.999359
# [27]	test-auc:0.990328	train-auc:0.999438
# [28]	test-auc:0.98954	train-auc:0.999494
# [29]	test-auc:0.989487	train-auc:0.999566
# [30]	test-auc:0.988383	train-auc:0.999595
# [31]	test-auc:0.987963	train-auc:0.999602
# [32]	test-auc:0.987857	train-auc:0.999742
# [33]	test-auc:0.988068	train-auc:0.999783
# [34]	test-auc:0.986754	train-auc:0.999858
# [35]	test-auc:0.986701	train-auc:0.99989
# [36]	test-auc:0.986543	train-auc:0.999911
# [37]	test-auc:0.985387	train-auc:0.999925
# [38]	test-auc:0.985387	train-auc:0.999942
# [39]	test-auc:0.985545	train-auc:0.999969
# [40]	test-auc:0.984441	train-auc:0.999976
# [41]	test-auc:0.984598	train-auc:0.999982
# [42]	test-auc:0.985807	train-auc:0.99999
# [43]	test-auc:0.985387	train-auc:0.999995
# [44]	test-auc:0.986123	train-auc:0.999995
# [45]	test-auc:0.987122	train-auc:0.999995
# [46]	test-auc:0.987332	train-auc:0.999996
# [47]	test-auc:0.987384	train-auc:0.999997
# [48]	test-auc:0.986964	train-auc:0.999997
# [49]	test-auc:0.987016	train-auc:0.999998
# [50]	test-auc:0.986964	train-auc:0.999999
# [51]	test-auc:0.987016	train-auc:0.999999
# [52]	test-auc:0.987857	train-auc:0.999999
# [53]	test-auc:0.988436	train-auc:0.999999
# [54]	test-auc:0.988278	train-auc:0.999999
# [55]	test-auc:0.988331	train-auc:0.999999
# [56]	test-auc:0.98812	train-auc:1
# [57]	test-auc:0.988225	train-auc:1
# [58]	test-auc:0.988488	train-auc:1
# [59]	test-auc:0.988225	train-auc:1
# [60]	test-auc:0.988804	train-auc:1
# [61]	test-auc:0.988541	train-auc:1
# [62]	test-auc:0.988383	train-auc:1
# [63]	test-auc:0.98812	train-auc:1
# [64]	test-auc:0.987752	train-auc:1
# [65]	test-auc:0.98812	train-auc:1
# [66]	test-auc:0.987489	train-auc:1
# [67]	test-auc:0.987122	train-auc:1
# [68]	test-auc:0.9877	train-auc:1
# [69]	test-auc:0.98812	train-auc:1
# [70]	test-auc:0.988488	train-auc:1
# [71]	test-auc:0.987805	train-auc:1
# [72]	test-auc:0.987437	train-auc:1
# [73]	test-auc:0.98791	train-auc:1
# [74]	test-auc:0.987963	train-auc:1
# [75]	test-auc:0.98812	train-auc:1
# [76]	test-auc:0.988225	train-auc:1
# [77]	test-auc:0.988751	train-auc:1
# [78]	test-auc:0.988331	train-auc:1
# [79]	test-auc:0.988856	train-auc:1
# [80]	test-auc:0.989119	train-auc:1
# [81]	test-auc:0.989224	train-auc:1
# [82]	test-auc:0.988751	train-auc:1
# [83]	test-auc:0.988593	train-auc:1
# [84]	test-auc:0.988909	train-auc:1
# [85]	test-auc:0.989014	train-auc:1
# [86]	test-auc:0.989066	train-auc:1
# [87]	test-auc:0.989224	train-auc:1
# [88]	test-auc:0.988856	train-auc:1
# [89]	test-auc:0.988593	train-auc:1
# [90]	test-auc:0.988488	train-auc:1
# [91]	test-auc:0.988488	train-auc:1
# [92]	test-auc:0.988804	train-auc:1
# [93]	test-auc:0.989382	train-auc:1
# [94]	test-auc:0.989172	train-auc:1
# [95]	test-auc:0.988593	train-auc:1
# [96]	test-auc:0.988436	train-auc:1
# [97]	test-auc:0.988015	train-auc:1
# [98]	test-auc:0.988173	train-auc:1
# [99]	test-auc:0.988383	train-auc:1
# [100]	test-auc:0.987963	train-auc:1
# [101]	test-auc:0.988331	train-auc:1
# [102]	test-auc:0.987963	train-auc:1
# [103]	test-auc:0.988173	train-auc:1
# [104]	test-auc:0.98812	train-auc:1
# [105]	test-auc:0.988015	train-auc:1
# [106]	test-auc:0.987857	train-auc:1
# [107]	test-auc:0.9877	train-auc:1
# [108]	test-auc:0.987227	train-auc:1
# [109]	test-auc:0.987069	train-auc:1
# [110]	test-auc:0.987332	train-auc:1
# [111]	test-auc:0.986754	train-auc:1
# [112]	test-auc:0.986281	train-auc:1
# [113]	test-auc:0.986964	train-auc:1
# [114]	test-auc:0.987016	train-auc:1
# [115]	test-auc:0.9877	train-auc:1
# [116]	test-auc:0.987437	train-auc:1
# [117]	test-auc:0.987489	train-auc:1
# [118]	test-auc:0.987384	train-auc:1
# [119]	test-auc:0.987332	train-auc:1
# [120]	test-auc:0.987963	train-auc:1
# [121]	test-auc:0.988173	train-auc:1
# [122]	test-auc:0.988015	train-auc:1
# [123]	test-auc:0.987805	train-auc:1
# [124]	test-auc:0.987963	train-auc:1
# [125]	test-auc:0.988225	train-auc:1
# [126]	test-auc:0.988383	train-auc:1
# [127]	test-auc:0.988068	train-auc:1
# [128]	test-auc:0.988225	train-auc:1
# [129]	test-auc:0.988278	train-auc:1
# [130]	test-auc:0.988541	train-auc:1
# [131]	test-auc:0.988856	train-auc:1
# [132]	test-auc:0.988961	train-auc:1
# [133]	test-auc:0.989172	train-auc:1
# [134]	test-auc:0.989382	train-auc:1
# [135]	test-auc:0.989382	train-auc:1
# [136]	test-auc:0.98954	train-auc:1
# [137]	test-auc:0.989645	train-auc:1
# [138]	test-auc:0.989592	train-auc:1
# [139]	test-auc:0.988909	train-auc:1
# [140]	test-auc:0.989066	train-auc:1
# [141]	test-auc:0.989014	train-auc:1
# [142]	test-auc:0.988698	train-auc:1
# [143]	test-auc:0.988909	train-auc:1
# [144]	test-auc:0.989329	train-auc:1
# [145]	test-auc:0.989382	train-auc:1
# [146]	test-auc:0.989119	train-auc:1
# [147]	test-auc:0.989224	train-auc:1
# [148]	test-auc:0.989592	train-auc:1
# [149]	test-auc:0.989645	train-auc:1
# [150]	test-auc:0.989487	train-auc:1
# [151]	test-auc:0.989329	train-auc:1
# [152]	test-auc:0.989645	train-auc:1
# [153]	test-auc:0.98996	train-auc:1
# [154]	test-auc:0.989855	train-auc:1
# [155]	test-auc:0.990065	train-auc:1
# [156]	test-auc:0.98975	train-auc:1
# Stopping. Best iteration:
# [56]	test-auc:0.98812	train-auc:1
#
# [0]	test-auc:0.654595	train-auc:0.764982
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	test-auc:0.855933	train-auc:0.904168
# [2]	test-auc:0.904667	train-auc:0.941346
# [3]	test-auc:0.935311	train-auc:0.966887
# [4]	test-auc:0.930101	train-auc:0.973678
# [5]	test-auc:0.931874	train-auc:0.974555
# [6]	test-auc:0.936107	train-auc:0.982543
# [7]	test-auc:0.947178	train-auc:0.98342
# [8]	test-auc:0.952677	train-auc:0.987622
# [9]	test-auc:0.951881	train-auc:0.98967
# [10]	test-auc:0.947576	train-auc:0.99086
# [11]	test-auc:0.945912	train-auc:0.992518
# [12]	test-auc:0.946382	train-auc:0.994086
# [13]	test-auc:0.951664	train-auc:0.995363
# [14]	test-auc:0.947829	train-auc:0.9963
# [15]	test-auc:0.950072	train-auc:0.996922
# [16]	test-auc:0.960709	train-auc:0.997318
# [17]	test-auc:0.963459	train-auc:0.997779
# [18]	test-auc:0.967294	train-auc:0.99799
# [19]	test-auc:0.964544	train-auc:0.998507
# [20]	test-auc:0.96165	train-auc:0.998666
# [21]	test-auc:0.959986	train-auc:0.999107
# [22]	test-auc:0.956295	train-auc:0.999187
# [23]	test-auc:0.959117	train-auc:0.999323
# [24]	test-auc:0.956946	train-auc:0.999487
# [25]	test-auc:0.959696	train-auc:0.999561
# [26]	test-auc:0.958032	train-auc:0.999687
# [27]	test-auc:0.956512	train-auc:0.999719
# [28]	test-auc:0.956006	train-auc:0.9997
# [29]	test-auc:0.959334	train-auc:0.999781
# [30]	test-auc:0.961939	train-auc:0.999757
# [31]	test-auc:0.961577	train-auc:0.999807
# [32]	test-auc:0.96165	train-auc:0.999856
# [33]	test-auc:0.962012	train-auc:0.999909
# [34]	test-auc:0.967004	train-auc:0.999942
# [35]	test-auc:0.968596	train-auc:0.999951
# [36]	test-auc:0.967873	train-auc:0.99995
# [37]	test-auc:0.967873	train-auc:0.999951
# [38]	test-auc:0.967221	train-auc:0.999965
# [39]	test-auc:0.968379	train-auc:0.999976
# [40]	test-auc:0.970767	train-auc:0.999985
# [41]	test-auc:0.972359	train-auc:0.999989
# [42]	test-auc:0.971418	train-auc:0.99999
# [43]	test-auc:0.970405	train-auc:0.999989
# [44]	test-auc:0.973082	train-auc:0.999992
# [45]	test-auc:0.972431	train-auc:0.999996
# [46]	test-auc:0.970116	train-auc:0.999998
# [47]	test-auc:0.96932	train-auc:0.999999
# [48]	test-auc:0.967728	train-auc:0.999998
# [49]	test-auc:0.967077	train-auc:0.999999
# [50]	test-auc:0.968234	train-auc:0.999998
# [51]	test-auc:0.968524	train-auc:0.999999
# [52]	test-auc:0.966932	train-auc:1
# [53]	test-auc:0.965557	train-auc:0.999999
# [54]	test-auc:0.966281	train-auc:0.999999
# [55]	test-auc:0.969465	train-auc:1
# [56]	test-auc:0.969682	train-auc:0.999999
# [57]	test-auc:0.969392	train-auc:0.999999
# [58]	test-auc:0.967149	train-auc:0.999999
# [59]	test-auc:0.967004	train-auc:0.999999
# [60]	test-auc:0.967004	train-auc:0.999999
# [61]	test-auc:0.967439	train-auc:0.999999
# [62]	test-auc:0.966425	train-auc:0.999999
# [63]	test-auc:0.966932	train-auc:1
# [64]	test-auc:0.966208	train-auc:1
# [65]	test-auc:0.965774	train-auc:1
# [66]	test-auc:0.96563	train-auc:1
# [67]	test-auc:0.965195	train-auc:1
# [68]	test-auc:0.965195	train-auc:1
# [69]	test-auc:0.964472	train-auc:1
# [70]	test-auc:0.965268	train-auc:1
# [71]	test-auc:0.965557	train-auc:1
# [72]	test-auc:0.965557	train-auc:1
# [73]	test-auc:0.966715	train-auc:1
# [74]	test-auc:0.968669	train-auc:1
# [75]	test-auc:0.967366	train-auc:1
# [76]	test-auc:0.968017	train-auc:1
# [77]	test-auc:0.969247	train-auc:1
# [78]	test-auc:0.968886	train-auc:1
# [79]	test-auc:0.969465	train-auc:1
# [80]	test-auc:0.969971	train-auc:1
# [81]	test-auc:0.968669	train-auc:1
# [82]	test-auc:0.968813	train-auc:1
# [83]	test-auc:0.969682	train-auc:1
# [84]	test-auc:0.968234	train-auc:1
# [85]	test-auc:0.967511	train-auc:1
# [86]	test-auc:0.96809	train-auc:1
# [87]	test-auc:0.969465	train-auc:1
# [88]	test-auc:0.968451	train-auc:1
# [89]	test-auc:0.968524	train-auc:1
# [90]	test-auc:0.96809	train-auc:1
# [91]	test-auc:0.969103	train-auc:1
# [92]	test-auc:0.968741	train-auc:1
# [93]	test-auc:0.968958	train-auc:1
# [94]	test-auc:0.96809	train-auc:1
# [95]	test-auc:0.967945	train-auc:1
# [96]	test-auc:0.968379	train-auc:1
# [97]	test-auc:0.969609	train-auc:1
# [98]	test-auc:0.970622	train-auc:1
# [99]	test-auc:0.970912	train-auc:1
# [100]	test-auc:0.970261	train-auc:1
# [101]	test-auc:0.969537	train-auc:1
# [102]	test-auc:0.969899	train-auc:1
# [103]	test-auc:0.969826	train-auc:1
# [104]	test-auc:0.969899	train-auc:1
# [105]	test-auc:0.970261	train-auc:1
# [106]	test-auc:0.970767	train-auc:1
# [107]	test-auc:0.969754	train-auc:1
# [108]	test-auc:0.96903	train-auc:1
# [109]	test-auc:0.968524	train-auc:1
# [110]	test-auc:0.969175	train-auc:1
# [111]	test-auc:0.969609	train-auc:1
# [112]	test-auc:0.968886	train-auc:1
# [113]	test-auc:0.968813	train-auc:1
# [114]	test-auc:0.968379	train-auc:1
# [115]	test-auc:0.968017	train-auc:1
# [116]	test-auc:0.968307	train-auc:1
# [117]	test-auc:0.967945	train-auc:1
# [118]	test-auc:0.968596	train-auc:1
# [119]	test-auc:0.968379	train-auc:1
# [120]	test-auc:0.968886	train-auc:1
# [121]	test-auc:0.969247	train-auc:1
# [122]	test-auc:0.968524	train-auc:1
# [123]	test-auc:0.968958	train-auc:1
# [124]	test-auc:0.969971	train-auc:1
# [125]	test-auc:0.969971	train-auc:1
# [126]	test-auc:0.969754	train-auc:1
# [127]	test-auc:0.970043	train-auc:1
# [128]	test-auc:0.969754	train-auc:1
# [129]	test-auc:0.969826	train-auc:1
# [130]	test-auc:0.969899	train-auc:1
# [131]	test-auc:0.969609	train-auc:1
# [132]	test-auc:0.969609	train-auc:1
# [133]	test-auc:0.970188	train-auc:1
# [134]	test-auc:0.970116	train-auc:1
# [135]	test-auc:0.970333	train-auc:1
# [136]	test-auc:0.97055	train-auc:1
# [137]	test-auc:0.970405	train-auc:1
# [138]	test-auc:0.969754	train-auc:1
# [139]	test-auc:0.970333	train-auc:1
# [140]	test-auc:0.96932	train-auc:1
# [141]	test-auc:0.968813	train-auc:1
# [142]	test-auc:0.968741	train-auc:1
# [143]	test-auc:0.968379	train-auc:1
# [144]	test-auc:0.967873	train-auc:1
# [145]	test-auc:0.968813	train-auc:1
# [146]	test-auc:0.969465	train-auc:1
# [147]	test-auc:0.969899	train-auc:1
# [148]	test-auc:0.969682	train-auc:1
# [149]	test-auc:0.970043	train-auc:1
# [150]	test-auc:0.969465	train-auc:1
# [151]	test-auc:0.96903	train-auc:1
# [152]	test-auc:0.968451	train-auc:1
# Stopping. Best iteration:
# [52]	test-auc:0.966932	train-auc:1
#
# [0]	test-auc:0.894174	train-auc:0.862926
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	test-auc:0.942539	train-auc:0.93975
# [2]	test-auc:0.945489	train-auc:0.9478
# [3]	test-auc:0.960607	train-auc:0.966076
# [4]	test-auc:0.962635	train-auc:0.968164
# [5]	test-auc:0.961867	train-auc:0.978165
# [6]	test-auc:0.962051	train-auc:0.981958
# [7]	test-auc:0.969764	train-auc:0.983399
# [8]	test-auc:0.973236	train-auc:0.985762
# [9]	test-auc:0.971208	train-auc:0.988691
# [10]	test-auc:0.9717	train-auc:0.989696
# [11]	test-auc:0.967275	train-auc:0.991321
# [12]	test-auc:0.963618	train-auc:0.992968
# [13]	test-auc:0.963557	train-auc:0.994429
# [14]	test-auc:0.968289	train-auc:0.995489
# [15]	test-auc:0.969457	train-auc:0.99623
# [16]	test-auc:0.967675	train-auc:0.997227
# [17]	test-auc:0.971423	train-auc:0.997767
# [18]	test-auc:0.973882	train-auc:0.997823
# [19]	test-auc:0.970809	train-auc:0.998028
# [20]	test-auc:0.970932	train-auc:0.998438
# [21]	test-auc:0.969211	train-auc:0.998942
# [22]	test-auc:0.972345	train-auc:0.999063
# [23]	test-auc:0.969272	train-auc:0.99917
# [24]	test-auc:0.967429	train-auc:0.999429
# [25]	test-auc:0.968781	train-auc:0.99959
# [26]	test-auc:0.969211	train-auc:0.999633
# [27]	test-auc:0.968781	train-auc:0.99971
# [28]	test-auc:0.966138	train-auc:0.999684
# [29]	test-auc:0.964971	train-auc:0.999763
# [30]	test-auc:0.962942	train-auc:0.999801
# [31]	test-auc:0.962758	train-auc:0.999843
# [32]	test-auc:0.961775	train-auc:0.999907
# [33]	test-auc:0.960792	train-auc:0.999931
# [34]	test-auc:0.962697	train-auc:0.999935
# [35]	test-auc:0.961345	train-auc:0.999943
# [36]	test-auc:0.959993	train-auc:0.999957
# [37]	test-auc:0.957166	train-auc:0.999966
# [38]	test-auc:0.960054	train-auc:0.999974
# [39]	test-auc:0.960361	train-auc:0.999982
# [40]	test-auc:0.959009	train-auc:0.999987
# [41]	test-auc:0.958333	train-auc:0.999982
# [42]	test-auc:0.957903	train-auc:0.999987
# [43]	test-auc:0.958456	train-auc:0.999989
# [44]	test-auc:0.958456	train-auc:0.999994
# [45]	test-auc:0.958272	train-auc:0.999995
# [46]	test-auc:0.959255	train-auc:0.999996
# [47]	test-auc:0.958579	train-auc:0.999996
# [48]	test-auc:0.958026	train-auc:0.999997
# [49]	test-auc:0.957412	train-auc:0.999997
# [50]	test-auc:0.957596	train-auc:0.999998
# [51]	test-auc:0.957412	train-auc:0.999997
# [52]	test-auc:0.957842	train-auc:0.999997
# [53]	test-auc:0.956182	train-auc:0.999999
# [54]	test-auc:0.955506	train-auc:0.999999
# [55]	test-auc:0.955752	train-auc:1
# [56]	test-auc:0.957903	train-auc:1
# [57]	test-auc:0.955629	train-auc:1
# [58]	test-auc:0.95692	train-auc:1
# [59]	test-auc:0.956305	train-auc:1
# [60]	test-auc:0.956674	train-auc:1
# [61]	test-auc:0.955998	train-auc:1
# [62]	test-auc:0.956551	train-auc:1
# [63]	test-auc:0.957719	train-auc:1
# [64]	test-auc:0.957104	train-auc:1
# [65]	test-auc:0.956551	train-auc:1
# [66]	test-auc:0.957227	train-auc:1
# [67]	test-auc:0.956121	train-auc:1
# [68]	test-auc:0.956858	train-auc:1
# [69]	test-auc:0.955752	train-auc:1
# [70]	test-auc:0.95483	train-auc:1
# [71]	test-auc:0.954892	train-auc:1
# [72]	test-auc:0.954523	train-auc:1
# [73]	test-auc:0.954277	train-auc:1
# [74]	test-auc:0.95483	train-auc:1
# [75]	test-auc:0.954339	train-auc:1
# [76]	test-auc:0.954031	train-auc:1
# [77]	test-auc:0.955506	train-auc:1
# [78]	test-auc:0.954585	train-auc:1
# [79]	test-auc:0.954523	train-auc:1
# [80]	test-auc:0.954585	train-auc:1
# [81]	test-auc:0.955629	train-auc:1
# [82]	test-auc:0.956428	train-auc:1
# [83]	test-auc:0.957903	train-auc:1
# [84]	test-auc:0.958886	train-auc:1
# [85]	test-auc:0.958702	train-auc:1
# [86]	test-auc:0.95821	train-auc:1
# [87]	test-auc:0.957596	train-auc:1
# [88]	test-auc:0.958395	train-auc:1
# [89]	test-auc:0.958702	train-auc:1
# [90]	test-auc:0.95821	train-auc:1
# [91]	test-auc:0.958026	train-auc:1
# [92]	test-auc:0.958026	train-auc:1
# [93]	test-auc:0.958333	train-auc:1
# [94]	test-auc:0.959685	train-auc:1
# [95]	test-auc:0.96073	train-auc:1
# [96]	test-auc:0.961222	train-auc:1
# [97]	test-auc:0.960361	train-auc:1
# [98]	test-auc:0.959685	train-auc:1
# [99]	test-auc:0.959931	train-auc:1
# [100]	test-auc:0.960853	train-auc:1
# [101]	test-auc:0.96073	train-auc:1
# [102]	test-auc:0.960238	train-auc:1
# [103]	test-auc:0.960853	train-auc:1
# [104]	test-auc:0.961222	train-auc:1
# [105]	test-auc:0.960792	train-auc:1
# [106]	test-auc:0.961222	train-auc:1
# [107]	test-auc:0.96073	train-auc:1
# [108]	test-auc:0.960976	train-auc:1
# [109]	test-auc:0.9603	train-auc:1
# [110]	test-auc:0.960177	train-auc:1
# [111]	test-auc:0.960484	train-auc:1
# [112]	test-auc:0.960054	train-auc:1
# [113]	test-auc:0.961099	train-auc:1
# [114]	test-auc:0.960361	train-auc:1
# [115]	test-auc:0.95944	train-auc:1
# [116]	test-auc:0.959317	train-auc:1
# [117]	test-auc:0.959194	train-auc:1
# [118]	test-auc:0.958948	train-auc:1
# [119]	test-auc:0.958518	train-auc:1
# [120]	test-auc:0.958272	train-auc:1
# [121]	test-auc:0.958518	train-auc:1
# [122]	test-auc:0.958641	train-auc:1
# [123]	test-auc:0.958886	train-auc:1
# [124]	test-auc:0.95944	train-auc:1
# [125]	test-auc:0.959993	train-auc:1
# [126]	test-auc:0.959685	train-auc:1
# [127]	test-auc:0.959194	train-auc:1
# [128]	test-auc:0.95944	train-auc:1
# [129]	test-auc:0.959317	train-auc:1
# [130]	test-auc:0.959808	train-auc:1
# [131]	test-auc:0.959317	train-auc:1
# [132]	test-auc:0.959808	train-auc:1
# [133]	test-auc:0.959747	train-auc:1
# [134]	test-auc:0.959317	train-auc:1
# [135]	test-auc:0.959071	train-auc:1
# [136]	test-auc:0.958456	train-auc:1
# [137]	test-auc:0.958764	train-auc:1
# [138]	test-auc:0.958579	train-auc:1
# [139]	test-auc:0.958026	train-auc:1
# [140]	test-auc:0.957965	train-auc:1
# [141]	test-auc:0.958149	train-auc:1
# [142]	test-auc:0.957473	train-auc:1
# [143]	test-auc:0.95821	train-auc:1
# [144]	test-auc:0.957965	train-auc:1
# [145]	test-auc:0.957473	train-auc:1
# [146]	test-auc:0.957412	train-auc:1
# [147]	test-auc:0.95735	train-auc:1
# [148]	test-auc:0.95692	train-auc:1
# [149]	test-auc:0.956428	train-auc:1
# [150]	test-auc:0.956244	train-auc:1
# [151]	test-auc:0.956613	train-auc:1
# [152]	test-auc:0.956551	train-auc:1
# [153]	test-auc:0.957289	train-auc:1
# [154]	test-auc:0.956613	train-auc:1
# [155]	test-auc:0.955752	train-auc:1
# Stopping. Best iteration:
# [55]	test-auc:0.955752	train-auc:1
#
# [0]	test-auc:0.705398	train-auc:0.785405
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	test-auc:0.786208	train-auc:0.910392
# [2]	test-auc:0.859988	train-auc:0.948699
# [3]	test-auc:0.865513	train-auc:0.959501
# [4]	test-auc:0.868475	train-auc:0.965812
# [5]	test-auc:0.855262	train-auc:0.965786
# [6]	test-auc:0.874706	train-auc:0.973938
# [7]	test-auc:0.866265	train-auc:0.978747
# [8]	test-auc:0.89328	train-auc:0.98296
# ...
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	test-auc:0.849895	train-auc:0.940678
# [2]	test-auc:0.856434	train-auc:0.960782
# [3]	test-auc:0.861875	train-auc:0.967838
# [4]	test-auc:0.853188	train-auc:0.970854
# [5]	test-auc:0.85987	train-auc:0.97881
# [6]	test-auc:0.882804	train-auc:0.984257
# [7]	test-auc:0.90137	train-auc:0.985248
# [8]	test-auc:0.90736	train-auc:0.98833
# [9]	test-auc:0.915951	train-auc:0.990379
# [10]	test-auc:0.92416	train-auc:0.991151
# [11]	test-auc:0.933085	train-auc:0.993822
# [12]	test-auc:0.936713	train-auc:0.99421
# [13]	test-auc:0.940244	train-auc:0.99492
# [14]	test-auc:0.942726	train-auc:0.9959
# [15]	test-auc:0.944349	train-auc:0.997067
# [16]	test-auc:0.947117	train-auc:0.997728
# [17]	test-auc:0.944444	train-auc:0.998056
# [18]	test-auc:0.944635	train-auc:0.998606
# [19]	test-auc:0.944731	train-auc:0.998967
# [20]	test-auc:0.94454	train-auc:0.999102
# [21]	test-auc:0.94096	train-auc:0.999195
# [22]	test-auc:0.942965	train-auc:0.999445
# [23]	test-auc:0.942679	train-auc:0.999575
# [24]	test-auc:0.944206	train-auc:0.999623
# [25]	test-auc:0.947213	train-auc:0.999669
# [26]	test-auc:0.945256	train-auc:0.999796
# [27]	test-auc:0.944874	train-auc:0.999859
# [28]	test-auc:0.940769	train-auc:0.999932
# [29]	test-auc:0.939719	train-auc:0.999959
# [30]	test-auc:0.941819	train-auc:0.999955
# [31]	test-auc:0.942058	train-auc:0.999964
# [32]	test-auc:0.938192	train-auc:0.999974
# [33]	test-auc:0.942631	train-auc:0.999987
# [34]	test-auc:0.943872	train-auc:0.999994
# [35]	test-auc:0.944158	train-auc:0.999996
# [36]	test-auc:0.945924	train-auc:0.999998
# [37]	test-auc:0.944969	train-auc:0.999999
# [38]	test-auc:0.942344	train-auc:0.999998
# [39]	test-auc:0.942297	train-auc:0.999999
# [40]	test-auc:0.942058	train-auc:1
# [41]	test-auc:0.944635	train-auc:1
# [42]	test-auc:0.946544	train-auc:0.999999
# [43]	test-auc:0.945829	train-auc:1
# [44]	test-auc:0.943442	train-auc:1
# [45]	test-auc:0.943681	train-auc:1
# [46]	test-auc:0.945829	train-auc:1
# [47]	test-auc:0.946783	train-auc:1
# [48]	test-auc:0.945256	train-auc:1
# [49]	test-auc:0.945208	train-auc:1
# [50]	test-auc:0.943108	train-auc:1
# [51]	test-auc:0.944635	train-auc:1
# [52]	test-auc:0.945733	train-auc:1
# [53]	test-auc:0.946974	train-auc:1
# [54]	test-auc:0.946783	train-auc:1
# [55]	test-auc:0.945733	train-auc:1
# [56]	test-auc:0.945494	train-auc:1
# [57]	test-auc:0.94621	train-auc:1
# [58]	test-auc:0.948454	train-auc:1
# [59]	test-auc:0.950029	train-auc:1
# [60]	test-auc:0.950792	train-auc:1
# [61]	test-auc:0.950076	train-auc:1
# [62]	test-auc:0.949838	train-auc:1
# [63]	test-auc:0.951031	train-auc:1
# [64]	test-auc:0.951556	train-auc:1
# [65]	test-auc:0.952463	train-auc:1
# [66]	test-auc:0.951174	train-auc:1
# [67]	test-auc:0.950888	train-auc:1
# [68]	test-auc:0.949933	train-auc:1
# [69]	test-auc:0.95041	train-auc:1
# [70]	test-auc:0.949265	train-auc:1
# [71]	test-auc:0.949217	train-auc:1
# [72]	test-auc:0.94979	train-auc:1
# [73]	test-auc:0.949551	train-auc:1
# [74]	test-auc:0.950076	train-auc:1
# [75]	test-auc:0.949313	train-auc:1
# [76]	test-auc:0.949981	train-auc:1
# [77]	test-auc:0.950076	train-auc:1
# [78]	test-auc:0.950649	train-auc:1
# [79]	test-auc:0.950935	train-auc:1
# [80]	test-auc:0.951604	train-auc:1
# [81]	test-auc:0.950888	train-auc:1
# [82]	test-auc:0.950172	train-auc:1
# [83]	test-auc:0.951365	train-auc:1
# [84]	test-auc:0.950506	train-auc:1
# [85]	test-auc:0.95127	train-auc:1
# [86]	test-auc:0.950601	train-auc:1
# [87]	test-auc:0.950363	train-auc:1
# [88]	test-auc:0.950554	train-auc:1
# [89]	test-auc:0.949026	train-auc:1
# [90]	test-auc:0.949647	train-auc:1
# [91]	test-auc:0.949599	train-auc:1
# [92]	test-auc:0.950315	train-auc:1
# [93]	test-auc:0.948883	train-auc:1
# [94]	test-auc:0.94874	train-auc:1
# [95]	test-auc:0.949026	train-auc:1
# [96]	test-auc:0.94917	train-auc:1
# [97]	test-auc:0.949074	train-auc:1
# [98]	test-auc:0.948883	train-auc:1
# [99]	test-auc:0.949074	train-auc:1
# [100]	test-auc:0.949504	train-auc:1
# [101]	test-auc:0.949551	train-auc:1
# [102]	test-auc:0.949313	train-auc:1
# [103]	test-auc:0.94831	train-auc:1
# [104]	test-auc:0.948215	train-auc:1
# [105]	test-auc:0.94812	train-auc:1
# [106]	test-auc:0.948072	train-auc:1
# [107]	test-auc:0.947738	train-auc:1
# [108]	test-auc:0.946544	train-auc:1
# [109]	test-auc:0.947117	train-auc:1
# [110]	test-auc:0.946831	train-auc:1
# [111]	test-auc:0.947451	train-auc:1
# [112]	test-auc:0.947451	train-auc:1
# [113]	test-auc:0.948406	train-auc:1
# [114]	test-auc:0.948501	train-auc:1
# [115]	test-auc:0.949074	train-auc:1
# [116]	test-auc:0.949217	train-auc:1
# [117]	test-auc:0.949122	train-auc:1
# [118]	test-auc:0.949504	train-auc:1
# [119]	test-auc:0.949265	train-auc:1
# [120]	test-auc:0.948597	train-auc:1
# [121]	test-auc:0.948835	train-auc:1
# [122]	test-auc:0.948549	train-auc:1
# [123]	test-auc:0.947976	train-auc:1
# [124]	test-auc:0.947451	train-auc:1
# [125]	test-auc:0.947356	train-auc:1
# [126]	test-auc:0.94726	train-auc:1
# [127]	test-auc:0.94726	train-auc:1
# [128]	test-auc:0.947165	train-auc:1
# [129]	test-auc:0.947404	train-auc:1
# [130]	test-auc:0.947308	train-auc:1
# [131]	test-auc:0.947404	train-auc:1
# [132]	test-auc:0.946974	train-auc:1
# [133]	test-auc:0.946735	train-auc:1
# [134]	test-auc:0.947022	train-auc:1
# [135]	test-auc:0.947308	train-auc:1
# [136]	test-auc:0.946831	train-auc:1
# [137]	test-auc:0.947356	train-auc:1
# [138]	test-auc:0.948072	train-auc:1
# [139]	test-auc:0.94769	train-auc:1
# [140]	test-auc:0.948072	train-auc:1
# Stopping. Best iteration:
# [40]	test-auc:0.942058	train-auc:1
#
# [0]	test-auc:0.819393	train-auc:0.905498
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	test-auc:0.817348	train-auc:0.934151
# [2]	test-auc:0.780112	train-auc:0.946903
# [3]	test-auc:0.801425	train-auc:0.95721
# [4]	test-auc:0.851549	train-auc:0.968387
# [5]	test-auc:0.860801	train-auc:0.971858
# [6]	test-auc:0.867431	train-auc:0.976884
# [7]	test-auc:0.886225	train-auc:0.982499
# [8]	test-auc:0.897418	train-auc:0.985194
# [9]	test-auc:0.899484	train-auc:0.986025
# [10]	test-auc:0.908323	train-auc:0.989598
# [11]	test-auc:0.917782	train-auc:0.992166
# [12]	test-auc:0.919723	train-auc:0.993598
# [13]	test-auc:0.923358	train-auc:0.995142
# [14]	test-auc:0.924577	train-auc:0.995437
# [15]	test-auc:0.929905	train-auc:0.996248
# [16]	test-auc:0.935068	train-auc:0.997468
# [17]	test-auc:0.933168	train-auc:0.998012
# [18]	test-auc:0.941925	train-auc:0.998429
# [19]	test-auc:0.941388	train-auc:0.998714
# [20]	test-auc:0.947542	train-auc:0.999066
# [21]	test-auc:0.951673	train-auc:0.999356
# [22]	test-auc:0.95221	train-auc:0.9996
# [23]	test-auc:0.950723	train-auc:0.999789
# [24]	test-auc:0.94936	train-auc:0.999868
# [25]	test-auc:0.947212	train-auc:0.999954
# [26]	test-auc:0.945188	train-auc:0.999976
# [27]	test-auc:0.946055	train-auc:0.999988
# [28]	test-auc:0.949195	train-auc:0.999994
# [29]	test-auc:0.949153	train-auc:1
# [30]	test-auc:0.949732	train-auc:0.999999
# [31]	test-auc:0.950888	train-auc:0.999999
# [32]	test-auc:0.950723	train-auc:1
# [33]	test-auc:0.950971	train-auc:1
# [34]	test-auc:0.949979	train-auc:1
# [35]	test-auc:0.949071	train-auc:1
# [36]	test-auc:0.95064	train-auc:1
# [37]	test-auc:0.95221	train-auc:1
# [38]	test-auc:0.949442	train-auc:1
# [39]	test-auc:0.94874	train-auc:1
# [40]	test-auc:0.947708	train-auc:1
# [41]	test-auc:0.947253	train-auc:1
# [42]	test-auc:0.946138	train-auc:1
# [43]	test-auc:0.945642	train-auc:1
# [44]	test-auc:0.948864	train-auc:1
# [45]	test-auc:0.949318	train-auc:1
# [46]	test-auc:0.947666	train-auc:1
# [47]	test-auc:0.948203	train-auc:1
# [48]	test-auc:0.947708	train-auc:1
# [49]	test-auc:0.946427	train-auc:1
# [50]	test-auc:0.945023	train-auc:1
# [51]	test-auc:0.942462	train-auc:1
# [52]	test-auc:0.942916	train-auc:1
# [53]	test-auc:0.943412	train-auc:1
# [54]	test-auc:0.943412	train-auc:1
# [55]	test-auc:0.943453	train-auc:1
# [56]	test-auc:0.943949	train-auc:1
# [57]	test-auc:0.942834	train-auc:1
# [58]	test-auc:0.943081	train-auc:1
# [59]	test-auc:0.943825	train-auc:1
# [60]	test-auc:0.942627	train-auc:1
# [61]	test-auc:0.942544	train-auc:1
# [62]	test-auc:0.943907	train-auc:1
# [63]	test-auc:0.943494	train-auc:1
# [64]	test-auc:0.942627	train-auc:1
# [65]	test-auc:0.943123	train-auc:1
# [66]	test-auc:0.942834	train-auc:1
# [67]	test-auc:0.942834	train-auc:1
# [68]	test-auc:0.944031	train-auc:1
# [69]	test-auc:0.944197	train-auc:1
# [70]	test-auc:0.944403	train-auc:1
# [71]	test-auc:0.944734	train-auc:1
# [72]	test-auc:0.944734	train-auc:1
# [73]	test-auc:0.946014	train-auc:1
# [74]	test-auc:0.945849	train-auc:1
# [75]	test-auc:0.946055	train-auc:1
# [76]	test-auc:0.94556	train-auc:1
# [77]	test-auc:0.945684	train-auc:1
# [78]	test-auc:0.945642	train-auc:1
# [79]	test-auc:0.945601	train-auc:1
# [80]	test-auc:0.946097	train-auc:1
# [81]	test-auc:0.946262	train-auc:1
# [82]	test-auc:0.946716	train-auc:1
# [83]	test-auc:0.945353	train-auc:1
# [84]	test-auc:0.944775	train-auc:1
# [85]	test-auc:0.94461	train-auc:1
# [86]	test-auc:0.944155	train-auc:1
# [87]	test-auc:0.943123	train-auc:1
# [88]	test-auc:0.943742	train-auc:1
# [89]	test-auc:0.943536	train-auc:1
# [90]	test-auc:0.943329	train-auc:1
# [91]	test-auc:0.942668	train-auc:1
# [92]	test-auc:0.943494	train-auc:1
# [93]	test-auc:0.945394	train-auc:1
# [94]	test-auc:0.945477	train-auc:1
# [95]	test-auc:0.947295	train-auc:1
# [96]	test-auc:0.947542	train-auc:1
# [97]	test-auc:0.947749	train-auc:1
# [98]	test-auc:0.947418	train-auc:1
# [99]	test-auc:0.946675	train-auc:1
# [100]	test-auc:0.945808	train-auc:1
# [101]	test-auc:0.946221	train-auc:1
# [102]	test-auc:0.946055	train-auc:1
# [103]	test-auc:0.945931	train-auc:1
# [104]	test-auc:0.946427	train-auc:1
# [105]	test-auc:0.946799	train-auc:1
# [106]	test-auc:0.946221	train-auc:1
# [107]	test-auc:0.946179	train-auc:1
# [108]	test-auc:0.945973	train-auc:1
# [109]	test-auc:0.946262	train-auc:1
# [110]	test-auc:0.946303	train-auc:1
# [111]	test-auc:0.946221	train-auc:1
# [112]	test-auc:0.946427	train-auc:1
# [113]	test-auc:0.946179	train-auc:1
# [114]	test-auc:0.946303	train-auc:1
# [115]	test-auc:0.945436	train-auc:1
# [116]	test-auc:0.945642	train-auc:1
# [117]	test-auc:0.944734	train-auc:1
# [118]	test-auc:0.945188	train-auc:1
# [119]	test-auc:0.945725	train-auc:1
# [120]	test-auc:0.945808	train-auc:1
# [121]	test-auc:0.945931	train-auc:1
# [122]	test-auc:0.946014	train-auc:1
# [123]	test-auc:0.94589	train-auc:1
# [124]	test-auc:0.945849	train-auc:1
# [125]	test-auc:0.945188	train-auc:1
# [126]	test-auc:0.944981	train-auc:1
# [127]	test-auc:0.944155	train-auc:1
# [128]	test-auc:0.944444	train-auc:1
# [129]	test-auc:0.944568	train-auc:1
# Stopping. Best iteration:
# [29]	test-auc:0.949153	train-auc:1
#
# [0]	test-auc:0.8774	train-auc:0.905118
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	test-auc:0.890385	train-auc:0.945558
# [2]	test-auc:0.895205	train-auc:0.954778
# [3]	test-auc:0.898799	train-auc:0.957732
# [4]	test-auc:0.918994	train-auc:0.969397
# [5]	test-auc:0.916417	train-auc:0.976605
# [6]	test-auc:0.915358	train-auc:0.979072
# [7]	test-auc:0.921861	train-auc:0.982937
# [8]	test-auc:0.924541	train-auc:0.985404
# [9]	test-auc:0.925434	train-auc:0.987989
# [10]	test-auc:0.925725	train-auc:0.989493
# [11]	test-auc:0.923024	train-auc:0.991428
# [12]	test-auc:0.92317	train-auc:0.992988
# [13]	test-auc:0.928862	train-auc:0.994513
# [14]	test-auc:0.932145	train-auc:0.995306
# [15]	test-auc:0.932934	train-auc:0.99654
# [16]	test-auc:0.933849	train-auc:0.997093
# [17]	test-auc:0.92907	train-auc:0.997949
# [18]	test-auc:0.930857	train-auc:0.998449
# [19]	test-auc:0.935511	train-auc:0.998788
# [20]	test-auc:0.93871	train-auc:0.999114
# [21]	test-auc:0.936259	train-auc:0.99929
# [22]	test-auc:0.936757	train-auc:0.999412
# [23]	test-auc:0.94137	train-auc:0.999638
# [24]	test-auc:0.94299	train-auc:0.999759
# [25]	test-auc:0.943198	train-auc:0.999835
# [26]	test-auc:0.941577	train-auc:0.999882
# [27]	test-auc:0.944112	train-auc:0.999923
# [28]	test-auc:0.944735	train-auc:0.99995
# [29]	test-auc:0.946854	train-auc:0.999976
# [30]	test-auc:0.94673	train-auc:0.999979
# [31]	test-auc:0.947644	train-auc:0.999975
# [32]	test-auc:0.945816	train-auc:0.999986
# [33]	test-auc:0.947228	train-auc:0.999983
# [34]	test-auc:0.948309	train-auc:0.999988
# [35]	test-auc:0.948267	train-auc:0.999992
# [36]	test-auc:0.949971	train-auc:0.999995
# [37]	test-auc:0.951259	train-auc:0.999995
# [38]	test-auc:0.951716	train-auc:0.999998
# [39]	test-auc:0.95263	train-auc:0.999998
# [40]	test-auc:0.954209	train-auc:0.999998
# [41]	test-auc:0.954001	train-auc:0.999999
# [42]	test-auc:0.955954	train-auc:0.999999
# [43]	test-auc:0.956328	train-auc:0.999999
# [44]	test-auc:0.957824	train-auc:1
# [45]	test-auc:0.957907	train-auc:1
# [46]	test-auc:0.958281	train-auc:1
# [47]	test-auc:0.959486	train-auc:1
# [48]	test-auc:0.959237	train-auc:1
# [49]	test-auc:0.96065	train-auc:1
# [50]	test-auc:0.961439	train-auc:1
# [51]	test-auc:0.961065	train-auc:1
# [52]	test-auc:0.95986	train-auc:1
# [53]	test-auc:0.960442	train-auc:1
# [54]	test-auc:0.960775	train-auc:1
# [55]	test-auc:0.962229	train-auc:1
# [56]	test-auc:0.962437	train-auc:1
# [57]	test-auc:0.961522	train-auc:1
# [58]	test-auc:0.961522	train-auc:1
# [59]	test-auc:0.961606	train-auc:1
# [60]	test-auc:0.960525	train-auc:1
# [61]	test-auc:0.96119	train-auc:1
# [62]	test-auc:0.961273	train-auc:1
# [63]	test-auc:0.962229	train-auc:1
# [64]	test-auc:0.963018	train-auc:1
# [65]	test-auc:0.963974	train-auc:1
# [66]	test-auc:0.963392	train-auc:1
# [67]	test-auc:0.963725	train-auc:1
# [68]	test-auc:0.963309	train-auc:1
# [69]	test-auc:0.963475	train-auc:1
# [70]	test-auc:0.963974	train-auc:1
# [71]	test-auc:0.963101	train-auc:1
# [72]	test-auc:0.963143	train-auc:1
# [73]	test-auc:0.963351	train-auc:1
# [74]	test-auc:0.963185	train-auc:1
# [75]	test-auc:0.963559	train-auc:1
# [76]	test-auc:0.963434	train-auc:1
# [77]	test-auc:0.963725	train-auc:1
# [78]	test-auc:0.963351	train-auc:1
# [79]	test-auc:0.963143	train-auc:1
# [80]	test-auc:0.963143	train-auc:1
# [81]	test-auc:0.964057	train-auc:1
# [82]	test-auc:0.964223	train-auc:1
# [83]	test-auc:0.964099	train-auc:1
# [84]	test-auc:0.964099	train-auc:1
# [85]	test-auc:0.963434	train-auc:1
# [86]	test-auc:0.963642	train-auc:1
# [87]	test-auc:0.963891	train-auc:1
# [88]	test-auc:0.964099	train-auc:1
# [89]	test-auc:0.963933	train-auc:1
# [90]	test-auc:0.963891	train-auc:1
# [91]	test-auc:0.9636	train-auc:1
# [92]	test-auc:0.963849	train-auc:1
# [93]	test-auc:0.965013	train-auc:1
# [94]	test-auc:0.965013	train-auc:1
# [95]	test-auc:0.96493	train-auc:1
# [96]	test-auc:0.964348	train-auc:1
# [97]	test-auc:0.964016	train-auc:1
# [98]	test-auc:0.964514	train-auc:1
# [99]	test-auc:0.963642	train-auc:1
# [100]	test-auc:0.964473	train-auc:1
# [101]	test-auc:0.963974	train-auc:1
# [102]	test-auc:0.964265	train-auc:1
# [103]	test-auc:0.964805	train-auc:1
# [104]	test-auc:0.964016	train-auc:1
# [105]	test-auc:0.963808	train-auc:1
# [106]	test-auc:0.963974	train-auc:1
# [107]	test-auc:0.964473	train-auc:1
# [108]	test-auc:0.964306	train-auc:1
# [109]	test-auc:0.963891	train-auc:1
# [110]	test-auc:0.96439	train-auc:1
# [111]	test-auc:0.963891	train-auc:1
# [112]	test-auc:0.964099	train-auc:1
# [113]	test-auc:0.963891	train-auc:1
# [114]	test-auc:0.963766	train-auc:1
# [115]	test-auc:0.963974	train-auc:1
# [116]	test-auc:0.964265	train-auc:1
# [117]	test-auc:0.96493	train-auc:1
# [118]	test-auc:0.964597	train-auc:1
# [119]	test-auc:0.964597	train-auc:1
# [120]	test-auc:0.964888	train-auc:1
# [121]	test-auc:0.965013	train-auc:1
# [122]	test-auc:0.965138	train-auc:1
# [123]	test-auc:0.965345	train-auc:1
# [124]	test-auc:0.965304	train-auc:1
# [125]	test-auc:0.965262	train-auc:1
# [126]	test-auc:0.965138	train-auc:1
# [127]	test-auc:0.965387	train-auc:1
# [128]	test-auc:0.965512	train-auc:1
# [129]	test-auc:0.965054	train-auc:1
# [130]	test-auc:0.964556	train-auc:1
# [131]	test-auc:0.964556	train-auc:1
# [132]	test-auc:0.964888	train-auc:1
# [133]	test-auc:0.964265	train-auc:1
# [134]	test-auc:0.964223	train-auc:1
# [135]	test-auc:0.964847	train-auc:1
# [136]	test-auc:0.964597	train-auc:1
# [137]	test-auc:0.964722	train-auc:1
# [138]	test-auc:0.965221	train-auc:1
# [139]	test-auc:0.965262	train-auc:1
# [140]	test-auc:0.965096	train-auc:1
# [141]	test-auc:0.965595	train-auc:1
# [142]	test-auc:0.965844	train-auc:1
# [143]	test-auc:0.965678	train-auc:1
# [144]	test-auc:0.966301	train-auc:1
# Stopping. Best iteration:
# [44]	test-auc:0.957824	train-auc:1
